# %%
import matplotlib.pyplot as plt
import random as rand
import numpy as np
rand.seed()
time = np.arange(0.0, 5.0, 0.1)
BM1 = np.zeros(52)
BM2 = np.zeros(52)
for i,t in enumerate(T):
    BM1[i+1] = BM1[i] + rand.choice([1,-1])
    temp = BM2[i] + rand.choice([1,-1]) - 0.1
    if (temp >= BM1[i+1]): BM2[i+1] = BM2[i] - 1 - 0.1
    else: BM2[i+1] = temp


plt.plot(T,BM1[:51], label = "Simple Brownian motion")
plt.plot(T,BM2[:51], label = "Shifted and reflected Brownian motion")
plt.xlabel("Time")
plt.ylabel("Brownian coordinate")
plt.grid()
plt.lgegen
